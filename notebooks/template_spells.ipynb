# %% [markdown]
# # An Example Spells Notebook

# %%
from opend6_tools.magic2 import *

# %%
spell = Spell(
# Details go here.
    name="Some Spell",
    effect=GenericEffect("Replace with real effect"),
)

# %% [markdown]
# The Python code for a **complete** spell.

# %%
print(repr(spell))

# %% [markdown]
# A more readable, detailed display.

# %%
print(display(spell))
# Out:
#   name                : 'Some Spell'
#   notes               : ''
#   skill               : 'Replace with real effect'
#   effect              :  +1 GenericEffect('Replace with real effect', 1)
# Effect Details        : GenericEffect based on
# Spell Total           : {'effect': 1} = 1
# Negative Modifiers    : {} = 0
# Difficulty            : ⎡(1 - 0) ÷ 2⎤ = 1
